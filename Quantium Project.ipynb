# %%
import pandas as pd
import seaborn as sns 
import numpy as np
import matplotlib as plt

# %%
df=pd.read_excel("QVI_transaction_data.xlsx")

# %%
df
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43605          1            1343     383        61
# 3       43329          2            2373     974        69
# 4       43330          2            2426    1038       108
# ...       ...        ...             ...     ...       ...
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  int64
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB

# %%
df['TOT_SALES'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 264831    False
# 264832    False
# 264833    False
# 264834    False
# 264835    False
# Name: TOT_SALES, Length: 264836, dtype: bool

# %%
df.columns
# Out:
# Index(['DATE', 'STORE_NBR', 'LYLTY_CARD_NBR', 'TXN_ID', 'PROD_NBR',
#        'PROD_NAME', 'PROD_QTY', 'TOT_SALES'],
#       dtype='object')

# %%
sns.boxplot(df['TOT_SALES'])
# Out:
# C:\Users\sudha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOT_SALES'>

# %%
df['PROD_QTY'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 264836 entries, 0 to 264835
# Series name: PROD_QTY
# Non-Null Count   Dtype
# --------------   -----
# 264836 non-null  int64
# dtypes: int64(1)
# memory usage: 2.0 MB

# %%
df1=pd.read_csv("QVI_purchase_behaviour.csv")

# %%
df1
# Out:
#        LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0                1000   YOUNG SINGLES/COUPLES          Premium
# 1                1002   YOUNG SINGLES/COUPLES       Mainstream
# 2                1003          YOUNG FAMILIES           Budget
# 3                1004   OLDER SINGLES/COUPLES       Mainstream
# 4                1005  MIDAGE SINGLES/COUPLES       Mainstream
# ...               ...                     ...              ...
# 72632         2370651  MIDAGE SINGLES/COUPLES       Mainstream
# 72633         2370701          YOUNG FAMILIES       Mainstream
# 72634         2370751          YOUNG FAMILIES          Premium
# 72635         2370961          OLDER FAMILIES           Budget
# 72636         2373711   YOUNG SINGLES/COUPLES       Mainstream
#
# [72637 rows x 3 columns]

# %%
df1.isnull().sum()
# Out:
# LYLTY_CARD_NBR      0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72637 entries, 0 to 72636
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    72637 non-null  int64
#  1   LIFESTAGE         72637 non-null  object
#  2   PREMIUM_CUSTOMER  72637 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
df3=pd.merge(df,df1,on='LYLTY_CARD_NBR')

# %%
df3
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43414          1            1307     346        96
# 3       43533          1            1307     347        54
# 4       43605          1            1343     383        61
# ...       ...        ...             ...     ...       ...
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES  \
# 0        Natural Chip        Compny SeaSalt175g         2        6.0
# 1                      CCs Nacho Cheese    175g         3        6.3
# ...

# %%
df3.columns
# Out:
# Index(['DATE', 'STORE_NBR', 'LYLTY_CARD_NBR', 'TXN_ID', 'PROD_NBR',
#        'PROD_NAME', 'PROD_QTY', 'TOT_SALES', 'LIFESTAGE', 'PREMIUM_CUSTOMER'],
#       dtype='object')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264836 entries, 0 to 264835
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DATE              264836 non-null  int64
#  1   STORE_NBR         264836 non-null  int64
#  2   LYLTY_CARD_NBR    264836 non-null  int64
#  3   TXN_ID            264836 non-null  int64
#  4   PROD_NBR          264836 non-null  int64
#  5   PROD_NAME         264836 non-null  object
#  6   PROD_QTY          264836 non-null  int64
#  7   TOT_SALES         264836 non-null  float64
#  8   LIFESTAGE         264836 non-null  object
#  9   PREMIUM_CUSTOMER  264836 non-null  object
# dtypes: float64(1), int64(6), object(3)
# memory usage: 22.2+ MB

# %%
Product_groups=df3.groupby(['PROD_NAME'],as_index=False)['TOT_SALES'].sum().sort_values(by='TOT_SALES',ascending=False).head(10)

# %%
sns.barplot(x='PROD_NAME',y='TOT_SALES',data=Product_groups)
sns.set(rc={'figure.figsize':(5,15)})

# %%
df3.to_excel('Quantium.xlsx')

# %%
df3
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43414          1            1307     346        96
# 3       43533          1            1307     347        54
# 4       43605          1            1343     383        61
# ...       ...        ...             ...     ...       ...
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES  \
# 0        Natural Chip        Compny SeaSalt175g         2        6.0
# 1                      CCs Nacho Cheese    175g         3        6.3
# ...

# %%
sns.barplot(x='PROD_NAME',y='PROD_QTY',data=Product_Quantity)
sns.set(rc={'figure.figsize':(5,5)})

# %%
sns.barplot(x='PROD_NAME',y='PROD_QTY',data=Product_Quantity)
sns.set(rc={'figure.figsize':(15,15)})

# %%
df3['PROD_NBR'].unique()
# Out:
# array([  5,  66,  96,  54,  61,  69, 108,  57,  70,  60,   4,  51,  16,
#         46, 112,  87,  24,  59,  93,  28,  42,  13,  84,  83,  44,  52,
#         90, 104, 114,  68,  78,  33,  15,  92,  53,  30,  97,  47,   7,
#         31,  32,  58,  10,  94,  98, 107,  80,  56,  91,  43,  34,  21,
#         41,  81,  99,  25,   1,  38,  11, 101,  65, 111, 113,  39,  63,
#        106,  89,  27, 110,   2,  26,  20,  64,  62,  22,  45, 102,  73,
#         48,  37,  36,  88, 109,  17, 103,  77,  74,   3,  75,  82,  35,
#         19,  40,  76,   9,  49,  23,  67, 100,  79,  71,   6,  85,  29,
#         12,  95,  86,   8,  50, 105,  14,  55,  72,  18], dtype=int64)

# %%
members=df3.groupby(['PREMIUM_CUSTOMER'],as_index=False)

# %%
prodname=df3.groupby(['PROD_NBR'],as_index=False)

# %%
df3["TOT_SALES"].sum()
# Out:
# 1934414.9999999998

# %%
df3.columns
# Out:
# Index(['DATE', 'STORE_NBR', 'LYLTY_CARD_NBR', 'TXN_ID', 'PROD_NBR',
#        'PROD_NAME', 'PROD_QTY', 'TOT_SALES', 'LIFESTAGE', 'PREMIUM_CUSTOMER'],
#       dtype='object')

# %%
stores=df.groupby(['STORE_NBR'],as_index=False)['TOT_SALES'].sum().sort_values('TOT_SALES',ascending=False).head(10)

# %%
ax=sns.barplot(x='STORE_NBR',y='TOT_SALES',data=stores)

# %%
df3.columns
# Out:
# Index(['DATE', 'STORE_NBR', 'LYLTY_CARD_NBR', 'TXN_ID', 'PROD_NBR',
#        'PROD_NAME', 'PROD_QTY', 'TOT_SALES', 'LIFESTAGE', 'PREMIUM_CUSTOMER'],
#       dtype='object')

# %%
customers=df3.groupby(['PROD_NBR'],as_index=False).head(10)
customers.head(10)
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43414          1            1307     346        96
# 3  43533          1            1307     347        54
# 4  43605          1            1343     383        61
# 5  43329          2            2373     974        69
# 6  43330          2            2426    1038       108
# 7  43604          4            4074    2982        57
# 8  43318          4            4074    2978        70
# 9  43321          4            4074    2979        60
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  \
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2            WW Original Stacked Chips 160g         2        3.8
# 3                         CCs Original 175g         1        2.1
# ...

# %%
l=df['PROD_NBR'].head(10)

# %%
members=df3.groupby(['PREMIUM_CUSTOMER'],as_index=False)['TOT_SALES'].sum().sort_values('TOT_SALES',ascending=False).head(10)

# %%
ax=sns.barplot(x='PREMIUM_CUSTOMER',y='TOT_SALES',data=members)
for bars in ax.containers:
    ax.bar_label(bars)
sns.set(rc={'figure.figsize':(15,15)})

# %%
df3
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43414          1            1307     346        96
# 3       43533          1            1307     347        54
# 4       43605          1            1343     383        61
# ...       ...        ...             ...     ...       ...
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES  \
# 0        Natural Chip        Compny SeaSalt175g         2        6.0
# 1                      CCs Nacho Cheese    175g         3        6.3
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264836 entries, 0 to 264835
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DATE              264836 non-null  int64
#  1   STORE_NBR         264836 non-null  int64
#  2   LYLTY_CARD_NBR    264836 non-null  int64
#  3   TXN_ID            264836 non-null  int64
#  4   PROD_NBR          264836 non-null  int64
#  5   PROD_NAME         264836 non-null  object
#  6   PROD_QTY          264836 non-null  int64
#  7   TOT_SALES         264836 non-null  float64
#  8   LIFESTAGE         264836 non-null  object
#  9   PREMIUM_CUSTOMER  264836 non-null  object
# dtypes: float64(1), int64(6), object(3)
# memory usage: 22.2+ MB

# %%
df3['DATE']=pd.to_datetime(df['DATE'])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264836 entries, 0 to 264835
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DATE              264836 non-null  datetime64[ns]
#  1   STORE_NBR         264836 non-null  int64
#  2   LYLTY_CARD_NBR    264836 non-null  int64
#  3   TXN_ID            264836 non-null  int64
#  4   PROD_NBR          264836 non-null  int64
#  5   PROD_NAME         264836 non-null  object
#  6   PROD_QTY          264836 non-null  int64
#  7   TOT_SALES         264836 non-null  float64
#  8   LIFESTAGE         264836 non-null  object
#  9   PREMIUM_CUSTOMER  264836 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 22.2+ MB

# %%
jupyter nbconvert --to pdf notebook.ipynb
# Out:
#   File "C:\Users\sudha\AppData\Local\Temp\ipykernel_10320\2930113816.py", line 1
#     jupyter nbconvert --to pdf notebook.ipynb
#             ^
# SyntaxError: invalid syntax

# %%
df3
# Out:
#                                 DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  \
# 0      1970-01-01 00:00:00.000043390          1            1000       1
# 1      1970-01-01 00:00:00.000043599          1            1307     348
# 2      1970-01-01 00:00:00.000043605          1            1307     346
# 3      1970-01-01 00:00:00.000043329          1            1307     347
# 4      1970-01-01 00:00:00.000043330          1            1343     383
# ...                              ...        ...             ...     ...
# 264831 1970-01-01 00:00:00.000043533        272          272319  270088
# 264832 1970-01-01 00:00:00.000043325        272          272358  270154
# 264833 1970-01-01 00:00:00.000043410        272          272379  270187
# 264834 1970-01-01 00:00:00.000043461        272          272379  270188
# 264835 1970-01-01 00:00:00.000043365        272          272380  270189
#
#         PROD_NBR                                PROD_NAME  PROD_QTY  \
# ...
